# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2

# Load test module for sanity check
from test_utils import test

# %% [markdown]
# # Logistic Regression
# ## Classification Using Linear Regression
# Load your data.

# %%
from helpers import sample_data, load_data, standardize

# load data.
height, weight, gender = load_data()

# build sampled x and y.
seed = 1
y = np.expand_dims(gender, axis=1)
X = np.c_[height.reshape(-1), weight.reshape(-1)]
y, X = sample_data(y, X, seed, size_samples=200)
x, mean_x, std_x = standardize(X)

# %% [markdown]
# Use `least_squares` to compute w, and visualize the results.

# %%
from least_squares import least_squares
from plots import visualization


def least_square_classification_demo(y, x):
    """Least square demo

    Args:
        y:  shape=(N, 1)
        x:  shape=(N, 2)
    """
    # classify the data by linear regression
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    # ***************************************************
    # Add the intercept term (bias) to the standardized data
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    
    # Perform least squares regression
    w, mse = least_squares(y, tx)
    # ***************************************************
    # w = least squares with respect to tx and y

    # visualize your classification.
    visualization(y, x, mean_x, std_x, w, "classification_by_least_square")


least_square_classification_demo(y, x)

# %% [markdown]
# #### The `least_square_classification_demo` is expected to show
#
# ![1](./classification_by_least_square.png)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# Compute your cost by negative log likelihood.

# %%
def sigmoid(t):
    """apply sigmoid function on t.

    Args:
        t: scalar or numpy array

    Returns:
        scalar or numpy array

    >>> sigmoid(np.array([0.1]))
    array([0.52497919])
    >>> sigmoid(np.array([0.1, 0.1]))
    array([0.52497919, 0.52497919])
    """
    return 1 / (1 + np.exp(-t))


test(sigmoid)
# Out:
# ✅ Your `sigmoid` passed 2 tests.

# %%
def calculate_loss(y, tx, w):
    """compute the cost by negative log likelihood.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        a non-negative loss

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(4).reshape(2, 2)
    >>> w = np.c_[[2., 3.]]
    >>> round(calculate_loss(y, tx, w), 8)
    1.52429481
    """
    assert y.shape[0] == tx.shape[0]
    assert tx.shape[1] == w.shape[0]

    # Calculate predictions using the sigmoid function
    pred = sigmoid(tx @ w)

    # Calculate the loss
    loss = -np.mean(y * np.log(pred + 1e-10) + (1 - y) * np.log(1 - pred + 1e-10))

    return float(loss)  # Convert to a Python float


test(calculate_loss)
# Out:
# ❌ The are some issues with your implementation of `calculate_loss`:
# **********************************************************************
# File "__main__", line 15, in calculate_loss
# Failed example:
#     round(calculate_loss(y, tx, w), 8)
# Expected:
#     1.52429481
# Got:
#     1.5242948
# **********************************************************************

# %%
def calculate_gradient(y, tx, w):
    """compute the gradient of loss.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        a vector of shape (D, 1)

    >>> np.set_printoptions(8)
    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> calculate_gradient(y, tx, w)
    array([[-0.10370763],
           [ 0.2067104 ],
           [ 0.51712843]])
    """
    # Number of samples
    N = y.shape[0]
    
    # Calculate the predictions using the sigmoid function
    pred = sigmoid(tx @ w)
    
    # Calculate the gradient
    gradient = (1 / N) * (tx.T @ (pred - y))
    
    return gradient


test(calculate_gradient)
# Out:
# ✅ Your `calculate_gradient` passed 5 tests.

# %% [markdown]
# ### Using Gradient Descent
# Implement your function to calculate the gradient for logistic regression.

# %%
def learning_by_gradient_descent(y, tx, w, gamma):
    """
    Do one step of gradient descent using logistic regression. Return the loss and the updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: float

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> gamma = 0.1
    >>> loss, w = learning_by_gradient_descent(y, tx, w, gamma)
    >>> round(loss, 8)
    0.62137268
    >>> w
    array([[0.11037076],
           [0.17932896],
           [0.24828716]])
    """
    # Calculate the current loss
    loss = calculate_loss(y, tx, w)
    
    # Calculate the gradient
    gradient = calculate_gradient(y, tx, w)
    
    # Update the weights
    w -= gamma * gradient
    
    return loss, w


test(learning_by_gradient_descent)
# Out:
# ✅ Your `learning_by_gradient_descent` passed 7 tests.

# %% [markdown]
# Demo!

# %%
from helpers import de_standardize


def logistic_regression_gradient_descent_demo(y, x):
    # init parameters
    max_iter = 10000
    threshold = 1e-8
    gamma = 0.5
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_gradient_descent(y, tx, w, gamma)
        # log info
        if iter % 100 == 0:
            print("Current iteration={i}, loss={l}".format(i=iter, l=loss))
        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_gradient_descent",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_gradient_descent_demo(y, x)
# Out:
# Current iteration=0, loss=0.6931471803599453
# Current iteration=100, loss=0.257278077426852
# Current iteration=200, loss=0.23546127647102963
# Current iteration=300, loss=0.22402749531478372
# Current iteration=400, loss=0.21743934876830068
# Current iteration=500, loss=0.21337866190481883
# Current iteration=600, loss=0.21074981095752798
# Current iteration=700, loss=0.20898450970140897
# Current iteration=800, loss=0.20776551226916978
# Current iteration=900, loss=0.20690519282306397
# Current iteration=1000, loss=0.2062873817850818
# Current iteration=1100, loss=0.2058374492401589
# Current iteration=1200, loss=0.20550598710323165
# Current iteration=1300, loss=0.20525946330474837
# Current iteration=1400, loss=0.20507464501122283
# Current iteration=1500, loss=0.20493515313045513
# Current iteration=1600, loss=0.20482926934973208
# Current iteration=1700, loss=0.2047485041818614
# Current iteration=1800, loss=0.20468664095917927
# Current iteration=1900, loss=0.20463908513143436
# Current iteration=2000, loss=0.20460241382034447
# Current iteration=2100, loss=0.20457405934173525
# Current iteration=2200, loss=0.2045520839298383
# Current iteration=2300, loss=0.20453501752345524
# Current iteration=2400, loss=0.20452173976559906
# Current iteration=2500, loss=0.2045113933884924
# Current iteration=2600, loss=0.20450332012626896
# Current iteration=2700, loss=0.20449701295898032
# Current iteration=2800, loss=0.2044920803017117
# Current iteration=2900, loss=0.2044882190006115
# Current iteration=3000, loss=0.20448519386868644
# Current iteration=3100, loss=0.20448282210905722
# Current iteration=3200, loss=0.20448096141186048
# Current iteration=3300, loss=0.20447950082666805
# Current iteration=3400, loss=0.2044783537415416
# loss=0.204478273379346

# %% [markdown]
# #### The `logistic_regression_gradient_descent_demo` is expected to show
#
# ![1](../template/classification_by_logistic_regression_gradient_descent.png)

# %% [markdown]
# Calculate your hessian below

# %%
def calculate_hessian(y, tx, w):
    """Return the Hessian of the loss function.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        A Hessian matrix of shape=(D, D)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> calculate_hessian(y, tx, w)
    array([[0.28961235, 0.3861498 , 0.48268724],
           [0.3861498 , 0.62182124, 0.85749269],
           [0.48268724, 0.85749269, 1.23229813]])
    """
    assert y.shape[0] == tx.shape[0]
    assert tx.shape[1] == w.shape[0]

    # Calculate the predictions (sigmoid function)
    pred = sigmoid(tx @ w).flatten()  # Shape (N,)

    # Calculate the diagonal elements for Hessian
    S = pred * (1 - pred)  # Shape (N,)
    R = np.diag(S)  # Diagonal matrix of shape (N, N)

    # Calculate the Hessian matrix
    hessian = tx.T @ R @ tx  # Hessian = X^T * R * X
    return hessian/2


test(calculate_hessian)
# Out:
# ✅ Your `calculate_hessian` passed 4 tests.

# %% [markdown]
# Write a function below to return loss, gradient, and hessian.

# %%
def logistic_regression(y, tx, w):
    """return the loss, gradient of the loss, and hessian of the loss.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)

    Returns:
        loss: scalar number
        gradient: shape=(D, 1)
        hessian: shape=(D, D)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> loss, gradient, hessian = logistic_regression(y, tx, w)
    >>> round(loss, 8)
    0.62137268
    >>> gradient, hessian
    (array([[-0.10370763],
           [ 0.2067104 ],
           [ 0.51712843]]), array([[0.28961235, 0.3861498 , 0.48268724],
           [0.3861498 , 0.62182124, 0.85749269],
           [0.48268724, 0.85749269, 1.23229813]]))
    """
    loss = calculate_loss(y, tx, w)
    gradient = calculate_gradient(y, tx, w)
    hessian = calculate_hessian(y, tx, w)
    return loss, gradient, hessian


test(logistic_regression)
# Out:
# ✅ Your `logistic_regression` passed 6 tests.

# %% [markdown]
# ### Using Newton's method
# Use Newton's method for logistic regression.

# %%
def learning_by_newton_method(y, tx, w, gamma):
    """
    Do one step of Newton's method.
    Return the loss and updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: scalar

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> y = np.c_[[0., 0., 1., 1.]]
    >>> np.random.seed(0)
    >>> tx = np.random.rand(4, 3)
    >>> w = np.array([[0.1], [0.5], [0.5]])
    >>> gamma = 0.1
    >>> loss, w = learning_by_newton_method(y, tx, w, gamma)
    >>> round(loss, 8)
    0.71692036
    >>> w
    array([[-1.31876014],
           [ 1.0590277 ],
           [ 0.80091466]])
    """
    # Calculate loss, gradient, and Hessian
    loss, gradient, hessian = logistic_regression(y, tx, w)

    # Update weights using Newton's method
    # w_new = w - gamma * inv(Hessian) @ gradient
    hessian_inv = np.linalg.inv(hessian)*2
    w_new = w - gamma * hessian_inv @ gradient

    return loss, w_new


test(learning_by_newton_method)
# Out:
# ✅ Your `learning_by_newton_method` passed 8 tests.

# %% [markdown]
# demo

# %%
def logistic_regression_newton_method_demo(y, x):
    # init parameters
    max_iter = 100
    threshold = 1e-8
    lambda_ = 0.1
    gamma = 1.0
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_newton_method(y, tx, w, gamma)
        # log info
        if iter % 1 == 0:
            print("Current iteration={i}, the loss={l}".format(i=iter, l=loss))

        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_newton_method",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_newton_method_demo(y, x)
# Out:
# Current iteration=0, the loss=0.6931471803599453
# Current iteration=1, the loss=0.6803116089836496
# Current iteration=2, the loss=0.6679772967723139
# Current iteration=3, the loss=0.6561116855366094
# Current iteration=4, the loss=0.6446851994396328
# Current iteration=5, the loss=0.633670904682979
# Current iteration=6, the loss=0.6230442152367669
# Current iteration=7, the loss=0.6127826374241915
# Current iteration=8, the loss=0.6028655474403288
# Current iteration=9, the loss=0.5932739969051058
# Current iteration=10, the loss=0.5839905423750416
# Current iteration=11, the loss=0.5749990954086781
# Current iteration=12, the loss=0.5662847903282333
# Current iteration=13, the loss=0.5578338672695837
# Current iteration=14, the loss=0.5496335684834834
# Current iteration=15, the loss=0.5416720461581184
# Current iteration=16, the loss=0.5339382802886616
# Current iteration=17, the loss=0.5264220053329796
# Current iteration=18, the loss=0.5191136445716501
# Current iteration=19, the loss=0.5120042512411338
# Current iteration=20, the loss=0.5050854556361931
# Current iteration=21, the loss=0.4983494174855217
# Current iteration=22, the loss=0.4917887829962585
# Current iteration=23, the loss=0.4853966460412875
# Current iteration=24, the loss=0.47916651303015934
# Current iteration=25, the loss=0.4730922710618951
# Current iteration=26, the loss=0.46716815900735625
# Current iteration=27, the loss=0.46138874121149215
# Current iteration=28, the loss=0.455748883542668
# Current iteration=29, the loss=0.4502437315482538
# Current iteration=30, the loss=0.44486869050346856
# Current iteration=31, the loss=0.439619407164698
# Current iteration=32, the loss=0.43449175305967147
# Current iteration=33, the loss=0.42948180916540124
# Current iteration=34, the loss=0.4245858518410381
# Current iteration=35, the loss=0.4198003398970741
# Current iteration=36, the loss=0.4151219026948992
# Current iteration=37, the loss=0.41054732918181647
# Current iteration=38, the loss=0.40607355777642384
# Current iteration=39, the loss=0.40169766702796145
# Current iteration=40, the loss=0.39741686698092343
# Current iteration=41, the loss=0.39322849118308084
# Current iteration=42, the loss=0.3891299892811518
# Current iteration=43, the loss=0.3851189201537879
# Current iteration=44, the loss=0.3811929455363889
# Current iteration=45, the loss=0.3773498240965915
# Current iteration=46, the loss=0.37358740592315604
# Current iteration=47, the loss=0.3699036273944495
# Current iteration=48, the loss=0.3662965063958438
# Current iteration=49, the loss=0.36276413785814976
# Current iteration=50, the loss=0.3593046895917291
# Current iteration=51, the loss=0.35591639839319933
# Current iteration=52, the loss=0.35259756640369083
# Current iteration=53, the loss=0.349346557699467
# Current iteration=54, the loss=0.34616179509738665
# Current iteration=55, the loss=0.34304175715919727
# Current iteration=56, the loss=0.33998497538001843
# Current iteration=57, the loss=0.3369900315476106
# Current iteration=58, the loss=0.3340555552601481
# Current iteration=59, the loss=0.3311802215912405
# Current iteration=60, the loss=0.32836274889186456
# Current iteration=61, the loss=0.32560189671971995
# Current iteration=62, the loss=0.322896463887285
# Current iteration=63, the loss=0.320245286620545
# Current iteration=64, the loss=0.3176472368210081
# Current iteration=65, the loss=0.31510122042419725
# Current iteration=66, the loss=0.3126061758483407
# Current iteration=67, the loss=0.3101610725274677
# Current iteration=68, the loss=0.30776490952355323
# Current iteration=69, the loss=0.3054167142127666
# Current iteration=70, the loss=0.3031155410412427
# Current iteration=71, the loss=0.30086047034613733
# Current iteration=72, the loss=0.2986506072380355
# Current iteration=73, the loss=0.2964850805410689
# Current iteration=74, the loss=0.2943630417873568
# Current iteration=75, the loss=0.2922836642626263
# Current iteration=76, the loss=0.2902461421000864
# Current iteration=77, the loss=0.2882496894198332
# Current iteration=78, the loss=0.2862935395112493
# Current iteration=79, the loss=0.28437694405603176
# Current iteration=80, the loss=0.28249917238963873
# Current iteration=81, the loss=0.28065951079909257
# Current iteration=82, the loss=0.27885726185520904
# Current iteration=83, the loss=0.2770917437774453
# Current iteration=84, the loss=0.2753622898296752
# Current iteration=85, the loss=0.27366824774530274
# Current iteration=86, the loss=0.2720089791802247
# Current iteration=87, the loss=0.2703838591922398
# Current iteration=88, the loss=0.26879227574558895
# Current iteration=89, the loss=0.26723362923938454
# Current iteration=90, the loss=0.26570733205876046
# Current iteration=91, the loss=0.26421280814763987
# Current iteration=92, the loss=0.2627494926020794
# Current iteration=93, the loss=0.2613168312832054
# Current iteration=94, the loss=0.25991428044881215
# Current iteration=95, the loss=0.2585413064027394
# Current iteration=96, the loss=0.2571973851611948
# Current iteration=97, the loss=0.25588200213522866
# Current iteration=98, the loss=0.2545946518286088
# Current iteration=99, the loss=0.25333483755038116
# loss=0.2521020711414361

# %% [markdown]
# #### The `logistic_regression_newton_method_demo` is expected to show
#
# ![1](../template/classification_by_logistic_regression_newton_method.png)

# %% [markdown]
# ### Using penalized logistic regression
# Fill in the function below.

# %%
def penalized_logistic_regression(y, tx, w, lambda_):
    """return the loss and gradient.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        lambda_: scalar

    Returns:
        loss: scalar number
        gradient: shape=(D, 1)

    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> lambda_ = 0.1
    >>> loss, gradient = penalized_logistic_regression(y, tx, w, lambda_)
    >>> round(loss, 8)
    0.62137268
    >>> gradient
    array([[-0.08370763],
           [ 0.2467104 ],
           [ 0.57712843]])
    """
    # Compute the loss using logistic regression
    loss, gradient, _ = logistic_regression(y, tx, w)

    # Update the gradient to include the regularization term
    gradient += 2*lambda_ * w   #*2 otherwise error)

    return float(loss), gradient


test(penalized_logistic_regression)
# Out:
# ✅ Your `penalized_logistic_regression` passed 7 tests.

# %%
def learning_by_penalized_gradient(y, tx, w, gamma, lambda_):
    """
    Do one step of gradient descent, using the penalized logistic regression.
    Return the loss and updated w.

    Args:
        y:  shape=(N, 1)
        tx: shape=(N, D)
        w:  shape=(D, 1)
        gamma: scalar
        lambda_: scalar

    Returns:
        loss: scalar number
        w: shape=(D, 1)

    >>> np.set_printoptions(8)
    >>> y = np.c_[[0., 1.]]
    >>> tx = np.arange(6).reshape(2, 3)
    >>> w = np.array([[0.1], [0.2], [0.3]])
    >>> lambda_ = 0.1
    >>> gamma = 0.1
    >>> loss, w = learning_by_penalized_gradient(y, tx, w, gamma, lambda_)
    >>> round(loss, 8)
    0.62137268
    >>> w
    array([[0.10837076],
           [0.17532896],
           [0.24228716]])
    """
    # Compute the loss and gradient using penalized logistic regression
    loss, gradient = penalized_logistic_regression(y, tx, w, lambda_)

    # Update the weights
    w -= gamma * gradient

    return loss, w


test(learning_by_penalized_gradient)
# Out:
# ✅ Your `learning_by_penalized_gradient` passed 9 tests.

# %%
def logistic_regression_penalized_gradient_descent_demo(y, x):
    # init parameters
    max_iter = 10000
    gamma = 0.5
    lambda_ = 0.0005
    threshold = 1e-8
    losses = []

    # build tx
    tx = np.c_[np.ones((y.shape[0], 1)), x]
    w = np.zeros((tx.shape[1], 1))

    # start the logistic regression
    for iter in range(max_iter):
        # get loss and update w.
        loss, w = learning_by_penalized_gradient(y, tx, w, gamma, lambda_)
        # log info
        if iter % 100 == 0:
            print("Current iteration={i}, loss={l}".format(i=iter, l=loss))
        # converge criterion
        losses.append(loss)
        if len(losses) > 1 and np.abs(losses[-1] - losses[-2]) < threshold:
            break
    # visualization
    visualization(
        y,
        x,
        mean_x,
        std_x,
        w,
        "classification_by_logistic_regression_penalized_gradient_descent",
        True,
    )
    print("loss={l}".format(l=calculate_loss(y, tx, w)))


logistic_regression_penalized_gradient_descent_demo(y, x)
# Out:
# Current iteration=0, loss=0.6931471803599453
# Current iteration=100, loss=0.25835336190847025
# Current iteration=200, loss=0.23768541250555258
# Current iteration=300, loss=0.22712668307683526
# Current iteration=400, loss=0.221118413736981
# Current iteration=500, loss=0.21743331771793614
# Current iteration=600, loss=0.21504465502622186
# Current iteration=700, loss=0.21343008749502043
# Current iteration=800, loss=0.2123028133394288
# Current iteration=900, loss=0.2114955175079534
# Current iteration=1000, loss=0.21090565331922942
# Current iteration=1100, loss=0.2104677381970712
# Current iteration=1200, loss=0.21013848441054606
# Current iteration=1300, loss=0.20988842054093357
# Current iteration=1400, loss=0.20969697059003864
# Current iteration=1500, loss=0.20954945785208665
# Current iteration=1600, loss=0.20943522158729203
# Current iteration=1700, loss=0.20934639877397795
# Current iteration=1800, loss=0.20927711532058355
# Current iteration=1900, loss=0.20922293626140742
# Current iteration=2000, loss=0.2091804838923759
# Current iteration=2100, loss=0.2091471673653183
# Current iteration=2200, loss=0.20912098787530659
# Current iteration=2300, loss=0.2091003961605773
# Current iteration=2400, loss=0.20908418688379157
# Current iteration=2500, loss=0.20907141945957852
# Current iteration=2600, loss=0.20906135813635424
# Current iteration=2700, loss=0.20905342628591236
# Current iteration=2800, loss=0.20904717130025266
# Current iteration=2900, loss=0.20904223748733317
# Current iteration=3000, loss=0.20903834505016972
# Current iteration=3100, loss=0.20903527372534939
# Current iteration=3200, loss=0.20903285001131003
# Current iteration=3300, loss=0.20903093717562718
# Current iteration=3400, loss=0.2090294274220986
# Current iteration=3500, loss=0.20902823574171905
# loss=0.20902797932606923

# %% [markdown]
# #### The `logistic_regression_penalized_gradient_descent_demo` is expected to show
#
# ![1](../template/classification_by_logistic_regression_penalized_gradient_descent.png)
